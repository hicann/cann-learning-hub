# %% [markdown]
# # 5 章节练习
#
# 1. 为什么 `soc_version` 必须与运行设备匹配？
# 2. 请写出图片从原始 HWC 格式到 ACL 输入 BIN 的预处理步骤。
# 3. 为什么 NMS 需要按类别分别处理？
# 4. 设计一个多流参数调优实验，说明需要固定哪些变量以及如何选择推荐参数。
#
# 参考答案见 [`answers/05_answer.txt`](./answers/05_answer.txt)。
