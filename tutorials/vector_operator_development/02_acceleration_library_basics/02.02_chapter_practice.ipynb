# %% [markdown]
# # 2.2 章节实践
#
# 完成本章学习后，通过以下题目检验学习成果。
#
# ---
#
# 1. （判断题）aclnn 单算子 API 采用两段式调用，会先调用 aclnnXXXGetWorkspaceSize 分配内存，然后调用 aclnnXXX 接口执行算子。
#
# 2. （单选题）静态图和动态图的主要区别是什么？
#     A. 静态图不支持Shape推导
#     B. 静态图Shape在编译时已知且明确，动态图Shape在编译时未知（包含-1或-2）
#     C. 动态图执行效率更高
#     D. 静态图不需要Tiling计算
#
# 3. （单选题）内核调用符 <<<>>> 的语法中，numBlocks 参数表示什么？
#     A. 每个线程块内的线程数量
#     B. 核函数配置的线程块个数（启用的核数）
#     C. 动态申请内存大小
#     D. 流同步标识
#
# 4. （单选题）TTK 动态编译（-d）模式的特点是什么？
#     A. 用固定 shape 编译后直接执行
#     B. 用动态 shape 编译，经 tiling 得到实际 shape 后执行
#     C. 将指定输入作为常量编译
#     D. 使用预编译的发布内核
#
# ---
#
# **执行以下代码获取答案。**
#
# ---
#
# [返回章节目录](./02.00_chapter_intro.ipynb) | [下一章：3.0 Ascend 算子开发](../03_ascend_operator_development/03.00_chapter_intro.ipynb)

# %%
# !cat ./answer/02.02_answer.txt
