# %% [markdown]
# # 2. 加速库基础
#
# 本章将深入介绍算子执行流程和加速库的使用方法，帮助你理解aclnn单算子API、GE图模式等不同执行模式的工作原理。
#
# ---
#
# ## 前置要求
#
# 为了充分掌握本章内容，你应已具备以下能力：
# - 已完成[基础掌握](../01_basic_mastery/01.00_chapter_intro.ipynb)章节的学习。
# - 理解算子的基本概念和开发流程。
# - 熟悉CANN异构计算架构的基本组成。
#
# 在环境配置方面，本章课程要求你的环境满足以下条件：
# - 系统中已部署昇腾NPU硬件，或已配置昇腾云服务器/仿真环境。
# - 已按照[CANN下载页面](https://www.hiascend.com/cann/download)完成对应硬件的开发环境部署。
#
# ---
#
# ## 章节目标
#
# 完成本课程后，你将能够：
# - 理解算子的多种执行模式及其应用场景。
# - 掌握aclnn单算子API执行流程的详细步骤。
# - 了解GE图模式的执行流程和必要交付件。
# - 理解Kernel直调等其他执行模式的特点。
#
# ---
#
# ## 章节内容
#
# * [2.0 章节介绍](02.00_chapter_intro.ipynb)
# * [2.1 算子执行流程](02.01_operator_execution_flow.ipynb)
#
# ---
#
# 本章课程请从[算子执行流程](02.01_operator_execution_flow.ipynb)开始学习。
