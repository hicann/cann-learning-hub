# %% [markdown]
# # 3.3 章节实践
#
# 完成本章学习后，通过以下题目检验学习成果。
#
# ---
#
# 1. （判断题）SIMT 算子开发适用于离散访问和复杂分支控制场景，如 ScatterUpdate 算子。
#
# 2. （判断题）TTK 使用 CSV 文件定义测试用例，支持批量测试多个场景。
#
# 3. （单选题）TTK 动态编译（-d）模式的特点是什么？
#     A. 用固定 shape 编译后直接执行
#     B. 用动态 shape 编译，经 tiling 得到实际 shape 后执行
#     C. 将指定输入作为常量编译
#     D. 使用预编译的发布内核
#
# 4. （单选题）性能数据文件 op_summary.csv 中，aiv_vec_ratio 字段表示什么？
#     A. AI Vector Core 总周期数
#     B. 向量计算占比（计算密集度）
#     C. 任务执行耗时
#     D. 内存搬运占比
#
# ---
#
# **执行以下代码获取答案。**
#
# ---
#
# [返回章节目录](./03.00_chapter_intro.ipynb)

# %%
# !cat ./answer/03.03_answer.txt
