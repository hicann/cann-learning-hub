# %% [markdown]
# # 1.4 章节实践
#
# 完成本章学习后，通过以下题目检验学习成果。
#
# ---
#
# 1. （判断题）SIMT 编程模型适用于离散访问和复杂分支控制场景。
#
# 2. （单选题）SIMT 线程架构中，一个线程块最多可以启用多少个线程？
#     A. 1024
#     B. 2048
#     C. 4096
#     D. 65535
#
# 3. （单选题）每个 Warp 包含多少个线程？
#     A. 16
#     B. 32
#     C. 64
#     D. 128
#
# 4. （单选题）Unified Buffer 总大小是多少？
#     A. 128KB
#     B. 256KB
#     C. 512KB
#     D. 1024KB
#
# 5. （单选题）Unified Buffer 中 Data Cache 的空间可配置范围是多少？
#     A. 8KB ~ 128KB
#     B. 16KB ~ 128KB
#     C. 32KB ~ 128KB
#     D. 64KB ~ 128KB
#
# ---
#
# **执行以下代码获取答案。**
#
# ---
#
# [返回章节目录](./01.00_chapter_intro.ipynb) | [下一章：2.0 算子加速库基础](../02_acceleration_library_basics/02.00_chapter_intro.ipynb)

# %%
# !cat ./answer/01.04_answer.txt
