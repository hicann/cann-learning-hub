# %% [markdown]
# # 第 3 章练习
#
# 本节通过五道题回顾 Wordle AgentLoop、奖励函数、数据准备和训练指标。

# %% [markdown]
# ## 综合练习
#
# ### 判断题
#
# 1. （判断题）环境反馈 token 的 `response_mask` 为 0 时，它不参与策略梯度计算，但仍会作为上下文影响模型的下一轮猜词。
#
# ### 单选题
#
# 2. （单选题）模型使用完整标签并在第 2 次有效猜词时猜中，`correct_answer=1.0`、`partial_answer=0`、`format_reward=1.0`。该轨迹的总奖励是多少？
#
#    A. 0.2
#
#    B. 0.7
#
#    C. 1.7
#
#    D. 2.2
#
# 3. （单选题）验证集包含 20 个测试词，`val_kwargs.n=5`。一次完整验证会生成多少条 rollout？
#
#    A. 20
#
#    B. 40
#
#    C. 100
#
#    D. 160
#
# ### 多选题
#
# 4. （多选题）训练日志中包含以下哪些类型的指标？
#
#    A. Actor 指标（entropy、loss、grad_norm）
#
#    B. verl 在 `critic/` 命名空间记录的奖励与优势指标（score、rewards、advantages）
#
#    C. 序列长度指标（prompt_length、response_length）
#
#    D. 性能指标（time_per_step、throughput）
#
# 5. （多选题）以下哪些参数直接影响 Wordle 任务或算法行为？
#
#    A. ROLLOUT_N（GRPO 组大小）
#
#    B. MAX_TURNS（最大猜词轮次）
#
#    C. ACTOR_LR（学习率）
#
#    D. NGPUS_PER_NODE（训练卡数，本课程中表示 NPU 卡数）

# %% [markdown]
# > 完成上面的练习后，再运行下方单元格查看参考答案和解析。

# %%
from pathlib import Path
import subprocess

repo_root = Path(subprocess.check_output(['git', 'rev-parse', '--show-toplevel'], text=True).strip())
course_root = repo_root if (repo_root / 'tutorials/rl_training_pipeline').is_dir() else repo_root.parent / 'cann-learning-hub'
answer_path = course_root / 'tutorials/rl_training_pipeline/03_wordle_rl_training/answer/03.05_answer.txt'
assert answer_path.is_file(), f'未找到答案文件: {answer_path}'
print(answer_path.read_text(encoding='utf-8'))
