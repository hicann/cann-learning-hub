# %% [markdown]
# # 章节练习
#
# 本章介绍了 Wordle 游戏规则、AgentLoop 设计、奖励函数、数据准备和训练指标解读。请根据学习内容完成以下题目进行自测。
#
# ---
#
# ## 选择题

# %% [markdown]
# 1. （判断题）Wordle 游戏中，G（Green）表示字母正确且位置正确，Y（Yellow）表示字母存在但位置错误。
#
# 2. （判断题）WordleAgentLoop 使用 response_mask 区分模型生成的 token 和环境追加的 token。
#
# 3. （判断题）Wordle 奖励函数中，猜中后仍会计算 partial_answer 分数。
#
# 4. （判断题）length_bonus 的值与猜测次数成反比，猜得越快奖励越高。
#
# 5. （判断题）format_reward 的权重是 0.2，远低于 correct_answer 的 1.0。
#
# 6. （判断题）训练数据中的秘密单词来自 TextArena Wordle-v0 的词表。
#
# 7. （判断题）验证指标 `val-aux/wordle/correct/mean@1` 表示训练集的猜中率。
#
# 8. （单选题）WordleAgentLoop 的 response_mask 中，值为 1 表示什么？
#     A. 环境追加的 token（不计算梯度）
#     B. 模型生成的 token（计算梯度）
#     C. 需要删除的 token
#     D. 无效的 token
#
# 9. （单选题）一个 3 轮猜中的 rollout，其 length_bonus 是多少？
#     A. 0.33
#     B. 0.5
#     C. 1.0
#     D. 3.0
#
# 10. （单选题）以下哪个不是 Wordle 奖励函数的组件？
#     A. correct_answer
#     B. partial_answer
#     C. format_reward
#     D. critic_value
#
# 11. （单选题）健康训练中 entropy 的典型表现是？
#     A. 持续快速上升到 5.0
#     B. 突然跌到 0
#     C. 缓慢下降但未崩塌
#     D. 保持不变
#
# 12. （多选题）WordleAgentLoop 的职责包括哪些？
#     A. 发送游戏 prompt
#     B. 接收模型猜词
#     C. 计算 G/Y/X 反馈
#     D. 追加反馈到对话
#
# 13. （多选题）以下哪些是训练崩塌的信号？
#     A. entropy 突然跌到 0
#     B. response_length 全部打满 3232
#     C. correct 率归零
#     D. reward 缓慢上升
#
# 14. （多选题）训练日志中包含以下哪些类型的指标？
#     A. Actor 指标（entropy、loss、grad_norm）
#     B. Critic 指标（score、rewards、advantages）
#     C. 序列长度指标（prompt_length、response_length）
#     D. 性能指标（time_per_step、throughput）
#
# 15. （多选题）以下哪些参数影响 Wordle RL 训练的行为？
#     A. ROLLOUT_N（GRPO 组大小）
#     B. MAX_TURNS（最大猜词轮次）
#     C. ACTOR_LR（学习率）
#     D. NGPUS_PER_NODE（训练卡数）

# %%
# !cat ../cann-learning-hub/tutorials/rl_training_pipeline/03_wordle_rl_training/answer/03.05_answer.txt
