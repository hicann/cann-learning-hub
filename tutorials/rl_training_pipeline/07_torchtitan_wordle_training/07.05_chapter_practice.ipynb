# %% [markdown]
# # 第 7 章练习
#
# 本节通过五道题回顾环境准备、配置确认和三步训练，以及各阶段需要关注的日志。

# %% [markdown]
# ## 综合练习
#
# ### 判断题
#
# 1. （判断题）同级训练代码目录已经存在时，环境准备 Cell 会复用当前分支和本地修改，而不会自动切换分支。
#
# 2. （判断题）三步任务未生成 checkpoint，就不能说明训练后端链路已经跑通。
#
# ### 单选题
#
# 3. （单选题）安装和启动脚本固定 ATB `--cxx_abi=1` 的主要原因是什么？
#
#    A. 与固定 PyTorch wheel 的 C++11 ABI 保持一致
#
#    B. 增加 Wordle 词表大小
#
#    C. 修改训练 batch size
#
#    D. 开启上下文并行
#
# ### 多选题
#
# 4. （多选题）三步训练设置 `SAVE_FREQ=-1` 与 `TEST_FREQ=-1` 的作用是什么？
#
#    A. 跳过 checkpoint 保存
#
#    B. 跳过训练后的末次验证
#
#    C. 保留核心三步训练链路
#
#    D. 缩小 batch 与 response 长度
#
# 5. （多选题）若三步任务在 Actor update 阶段失败，应保留哪些信息用于定位？
#
#    A. Actor worker 的首个异常
#
#    B. 当前 FSDP2、offload 与 TND 配置
#
#    C. 对应 step 的有效 token 和阶段耗时
#
#    D. 与本次进程无关的历史日志

# %% [markdown]
# > 完成练习后，运行下方单元格查看参考答案和解析。

# %%
from pathlib import Path
import subprocess

course_root = Path(subprocess.check_output(['git', 'rev-parse', '--show-toplevel'], text=True).strip())
answer_path = course_root / 'tutorials/rl_training_pipeline/07_torchtitan_wordle_training/answer/07.05_answer.txt'
assert answer_path.is_file(), f'未找到答案文件: {answer_path}'
print(answer_path.read_text(encoding='utf-8'))
