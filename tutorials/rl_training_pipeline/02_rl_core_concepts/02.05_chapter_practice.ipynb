# %% [markdown]
# # 第 2 章练习
#
# 本节通过五道题回顾策略与奖励、PPO、GRPO、KL 正则和训练稳定性。

# %% [markdown]
# ## 综合练习
#
# ### 判断题
#
# 1. （判断题）在 GRPO 中，如果同一组 rollout 的奖励都增加相同数值，按组内均值和标准差计算的相对优势不会改变。
#
# ### 单选题
#
# 2. （单选题）同一 prompt 的三条 rollout 奖励分别为 0.2、0.8 和 1.4。以组内平均奖励为 baseline 时，哪条 rollout 的优势为 0？
#
#    A. 奖励为 0.2 的 rollout
#
#    B. 奖励为 0.8 的 rollout
#
#    C. 奖励为 1.4 的 rollout
#
#    D. 三条 rollout 的优势都为 0
#
# 3. （单选题）训练中 KL 持续快速增大，当前策略明显偏离参考策略时，应优先检查哪个配置？
#
#    A. `entropy_coeff`
#
#    B. `kl_loss_coef`
#
#    C. `rollout.n`
#
#    D. `max_user_turns`
#
# ### 多选题
#
# 4. （多选题）以下哪些是 PPO 算法的组成部分？
#
#    A. Critic 模型估计价值
#
#    B. Clip 机制限制更新幅度
#
#    C. 组内相对优势
#
#    D. 策略梯度
#
# 5. （多选题）以下哪些指标可以用于判断 RL 训练是否健康？
#
#    A. entropy
#
#    B. kl_loss
#
#    C. grad_norm
#
#    D. response_length

# %% [markdown]
# > 完成上面的练习后，再运行下方单元格查看参考答案和解析。

# %%
from pathlib import Path
import subprocess

repo_root = Path(subprocess.check_output(['git', 'rev-parse', '--show-toplevel'], text=True).strip())
course_root = repo_root if (repo_root / 'tutorials/rl_training_pipeline').is_dir() else repo_root.parent / 'cann-learning-hub'
answer_path = course_root / 'tutorials/rl_training_pipeline/02_rl_core_concepts/answer/02.05_answer.txt'
assert answer_path.is_file(), f'未找到答案文件: {answer_path}'
print(answer_path.read_text(encoding='utf-8'))
