# %% [markdown]
# # 第 8 章综合练习
#
# 最后通过五道题串联训练后端切换、配置映射、TorchTitan-NPU 特性和三步实践。

# %% [markdown]
# ## 综合练习
#
# ### 判断题
#
# 1. （判断题）检查点恢复成功是证明训练后端已经完成切换的必要条件。
#
# 2. （判断题）TND 变长注意力可以减少 padding 带来的无效计算，但不会改变 packed batch 中各样本的逻辑边界。
#
# ### 单选题
#
# 3. （单选题）Actor 更新成功后，后续 rollout 行为长期没有反映新策略，应优先检查哪个边界？
#
#    A. Actor 到 vLLM 的权重同步
#
#    B. Wordle parquet 生成
#
#    C. CANN 环境变量加载
#
#    D. CP degree 规划
#
# ### 多选题
#
# 4. （多选题）设计 FSDP 与 TorchTitan 后端性能对比时，应固定哪些条件？
#
#    A. 模型、数据与 seed
#
#    B. batch、rollout 数和长度配置
#
#    C. 预热与重复次数
#
#    D. AgentLoop 和奖励语义
#
# 5. （多选题）长序列任务计划启用 CP 前，应确认哪些条件？
#
#    A. 序列激活或注意力显存构成瓶颈
#
#    B. 注意力头数与 CP degree 满足整除约束
#
#    C. packed 边界、补齐和结果还原路径已经适配
#
#    D. 硬件拓扑能够承担额外 collective 通信

# %% [markdown]
# > 完成练习后，运行下方单元格查看参考答案和解析。

# %%
from pathlib import Path
import subprocess

course_root = Path(subprocess.check_output(['git', 'rev-parse', '--show-toplevel'], text=True).strip())
answer_path = course_root / 'tutorials/rl_training_pipeline/08_validation_and_troubleshooting/answer/08.03_answer.txt'
assert answer_path.is_file(), f'未找到答案文件: {answer_path}'
print(answer_path.read_text(encoding='utf-8'))
