# %% [markdown]
# # 章节练习
#
# 本章介绍了 RL 训练环境的搭建和 verl 框架架构。请根据学习内容完成以下题目进行自测。
#
# ---
#
# ## 选择题

# %% [markdown]
# 1. （判断题）RL 训练与 SFT 训练的核心区别在于：RL 不需要标准答案，而是通过奖励函数对模型生成的回复打分。
#
# 2. （判断题）vLLM 在 RL 训练中的作用是计算梯度并更新模型参数。
#
# 3. （判断题）verl 框架基于 Ray 构建，使用 TaskRunner 调度推理、奖励、训练循环。
#
# 4. （判断题）Hybrid Engine 通过时分复用让 2 卡环境即可完成 RL 训练，训练和推理交替占用同一组卡。
#
# 5. （判断题）Wordle AgentLoop 补丁通过 `git apply` 应用到 verl 源码中，会修改 verl 的 `__init__.py` 注册 WordleAgentLoop。
#
# 6. （单选题）以下哪个不是 RL 训练的必要组件？
#     A. 推理引擎（vLLM）
#     B. 奖励函数
#     C. 标准答案标注数据
#     D. 训练框架（verl）
#
# 7. （单选题）verl 安装后，以下哪个依赖需要单独安装？
#     A. ray
#     B. pandas
#     C. nltk
#     D. pyarrow
#
# 8. （单选题）Hybrid Engine 中 `param_offload=True` 的作用是？
#     A. 将优化器状态卸载到 GPU
#     B. 将训练参数卸载到 CPU，释放显存给 vLLM
#     C. 将 vLLM 模型卸载到 CPU
#     D. 禁用参数更新
#
# 9. （单选题）在 verl 架构中，AgentLoopManager 的职责是？
#     A. 管理模型参数更新
#     B. 管理多个 AgentLoop Worker 并行处理 rollout
#     C. 提供 OpenAI API 接口
#     D. 计算 reward
#
# 10. （多选题）以下哪些是 RL 相比 SFT 的优势？
#     A. 不需要人工标注标准答案
#     B. 适合多轮决策场景
#     C. 训练速度更快
#     D. 可以通过试错优化策略
#
# 11. （多选题）Wordle RL 训练环境需要安装以下哪些组件？
#     A. vLLM
#     B. vLLM-Ascend
#     C. verl
#     D. torchtitan
#
# 12. （多选题）以下哪些是 verl 框架的核心组件？
#     A. TaskRunner
#     B. AgentLoopManager
#     C. vLLM Server
#     D. Ray Train (FSDP)

# %% [markdown]
# > 完成上面的练习后，再运行下方单元格查看参考答案和解析。

# %%
from pathlib import Path
import subprocess

repo_root = Path(subprocess.check_output(['git', 'rev-parse', '--show-toplevel'], text=True).strip())
course_root = repo_root if (repo_root / 'tutorials/rl_training_pipeline').is_dir() else repo_root.parent / 'cann-learning-hub'
answer_path = course_root / 'tutorials/rl_training_pipeline/01_environment_setup/answer/01.04_answer.txt'
assert answer_path.is_file(), f'未找到答案文件: {answer_path}'
print(answer_path.read_text(encoding='utf-8'))
