# %% [markdown]
# # 第 1 章练习
#
# 本节通过五道题回顾 RL 训练环境、verl 框架架构和 Hybrid Engine。

# %% [markdown]
# ## 综合练习
#
# ### 单选题
#
# 1. （单选题）Hybrid Engine 中 `param_offload=True` 的作用是？
#
#    A. 将优化器状态卸载到 CPU
#
#    B. 将训练参数卸载到 CPU，释放 NPU 设备内存供 vLLM-Ascend rollout 使用
#
#    C. 将 vLLM 模型卸载到 CPU
#
#    D. 禁用参数更新
#
# 2. （单选题）在 verl 架构中，AgentLoopManager 的职责是？
#
#    A. 管理模型参数更新
#
#    B. 管理多个 AgentLoop Worker 并行处理 rollout
#
#    C. 提供 OpenAI API 接口
#
#    D. 计算 reward
#
# ### 多选题
#
# 3. （多选题）以下哪些是 RL 相比 SFT 的优势？
#
#    A. 不依赖逐 token 人工标注的示范回复
#
#    B. 适合多轮决策场景
#
#    C. 训练速度更快
#
#    D. 可以通过试错优化策略
#
# 4. （多选题）本章初阶 Wordle RL 训练路径需要安装以下哪些组件？
#
#    A. vLLM
#
#    B. vLLM-Ascend
#
#    C. verl
#
#    D. torchtitan
#
# 5. （多选题）以下哪些是 verl 框架的核心组件？
#
#    A. TaskRunner
#
#    B. AgentLoopManager
#
#    C. vLLM Server
#
#    D. Ray Train (FSDP)

# %% [markdown]
# > 完成上面的练习后，再运行下方单元格查看参考答案和解析。

# %%
from pathlib import Path
import subprocess

repo_root = Path(subprocess.check_output(['git', 'rev-parse', '--show-toplevel'], text=True).strip())
course_root = repo_root if (repo_root / 'tutorials/rl_training_pipeline').is_dir() else repo_root.parent / 'cann-learning-hub'
answer_path = course_root / 'tutorials/rl_training_pipeline/01_environment_setup/answer/01.04_answer.txt'
assert answer_path.is_file(), f'未找到答案文件: {answer_path}'
print(answer_path.read_text(encoding='utf-8'))
