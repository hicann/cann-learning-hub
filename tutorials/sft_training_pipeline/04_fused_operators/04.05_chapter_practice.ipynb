# %% [markdown]
# # 章节练习
#
# 本章介绍了融合算子的原理、实现、Profiling 实操和结果分析。请根据学习内容完成以下题目进行自测。
#
# ---
#
# ## 选择题

# %% [markdown]
# # 章节练习
#
# 本章介绍了融合算子的原理、实现、Profiling 实操和结果分析。请根据学习内容完成以下题目进行自测。
#
# ---
#
# ## 选择题
#
# 1. （判断题）Qwen3-1.7B 中每层有 4 个 RMSNorm，28 层共 112 个 RMSNorm 实例。
#
# 2. （判断题）`NpuRMSNormConverter.convert()` 只会替换模型中 `isinstance(module, RMSNorm)` 为 `True` 的模块。
#
# 3. （判断题）Profiling 时 `global_batch_size` 设得比正式训练小，因为 profiling 只关心算子耗时，不关心收敛质量。
#
# 4. （单选题）以下哪个不是原生 PyTorch RMSNorm 被展开后的 kernel 步骤？
#     A. `aclnnPowTensorScalar`
#     B. `aclnnReduceMean`
#     C. `aclnnBatchMatMul`
#     D. `aclnnMul`
#
# 5. （单选题）`@register_model_converter("npu_rms_norm")` 装饰器的作用是什么？
#     A. 直接替换模型中的 RMSNorm
#     B. 将名字到配置类的映射写入全局注册表
#     C. 初始化 NPURMSNorm 参数
#     D. 检查环境是否支持融合算子
#
# 6. （单选题）确认融合算子生效的最直接证据是什么？
#     A. 显存占用降低
#     B. 模型参数量减少
#     C. fused trace 中出现 `npu::npu_rms_norm` 而 baseline trace 中没有
#     D. loss 值变小
#
# 7. （多选题）以下哪些是算子碎片化导致的问题？
#     A. Kernel launch overhead 增大
#     B. HBM 访存次数增加
#     C. 模型参数量变大
#     D. 计算单元（Cube）利用率降低
#
# 8. （多选题）`analyze_profile.py` 脚本能完成以下哪些工作？
#     A. 自动发现 `profile_traces/` 下的所有 trace_view.json
#     B. 按修改时间自动区分 baseline 和 fused
#     C. 按算子名分类统计算子耗时
#     D. 自动修复环境配置问题

# %%
# !cat ./answer/04.05_answer.txt
