# %% [markdown]
# # 章节练习
#
# 本章介绍了 FSDP 分布式训练、TorchTitan 框架以及环境配置。请根据学习内容完成以下题目进行自测。
#
# ---
#
# ## 综合练习

# %% [markdown]
# 1. （判断题）`NGPU=2` 会启动 2 个训练进程，单机 world size 也为 2。
#
# 2. （单选题）FULL_SHARD 在 forward 前执行 all-gather 时，收集的是什么？
#     A. 当前 FSDP unit 的参数组
#     B. 所有训练数据
#     C. 全部 optimizer state
#     D. profiler trace
#
# 3. （单选题）reduce-scatter 在 backward 中完成什么？
#     A. 归约各 rank 的梯度贡献，并让每个 rank 保留一个 gradient shard
#     B. 把完整模型复制到每个 rank
#     C. 下载 checkpoint
#     D. 切分 input token
#
# 4. （单选题）第 2 章运行 `NGPU=2 bash scripts/run_train.sh` 的主要目的是什么？
#     A. 检查当前 master 默认 recipe 的两 rank 训练入口
#     B. 完成正式 Wordle SFT
#     C. 启动推理服务器
#     D. 生成 profiler 对比报告
#
# 5. （单选题）`parallelize_fn=parallelize_qwen3` 的作用是什么？
#     A. 下载数据集
#     B. 根据配置进入 Qwen3 的 CP、TP、FSDP/DDP 等并行路径
#     C. 转换模型为 ONNX
#     D. 启动推理服务
#
# 6. （单选题）FULL_SHARD 相比每个 rank 保存完整副本的主要容量优势是什么？
#     A. 降低每个 rank 保存的模型状态显存
#     B. 消除所有通信
#     C. 自动提高模型精度
#     D. 自动缩短序列
#
# 7. （单选题）`reshard_after_forward` 主要控制什么？
#     A. forward 后是否恢复参数分片
#     B. tokenizer 词表大小
#     C. 数据集 revision
#     D. 推理端口
#
# 8. （单选题）本课程 `CP=1`、`dp_shard=2` 时，有效 FSDP mesh degree 是多少？
#     A. 1
#     B. 2
#     C. 4
#     D. 由 `seq_len` 决定
#
# 9. （多选题）TorchTitan 提供哪些训练框架能力？
#     A. 分布式并行配置
#     B. 数据加载与 checkpoint
#     C. 模型注册与 converter
#     D. 替代 NPU 驱动
#
# 10. （多选题）环境准备完成后应确认哪些结果？
#     A. checkout 位于 `master` 分支
#     B. requirements 与 editable package 已安装
#     C. 两 rank debug 训练完成且 loss/grad_norm 有限
#     D. 已编译 CANN 源码

# %%
# !cat ./answer/02.04_answer.txt
