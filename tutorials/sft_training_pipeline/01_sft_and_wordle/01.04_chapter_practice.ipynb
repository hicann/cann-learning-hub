# %% [markdown]
# # 章节练习
#
# 本章介绍了 Wordle 任务和 SFT 的核心概念。请根据学习内容完成以下题目进行自测。
#
# ---
#
# ## 综合练习

# %% [markdown]
# 1. （判断题）目标词为 `APPLE`、猜词为 `ALLEY` 时，逐位反馈是 `G Y X Y X`。
#
# 2. （判断题）标准 Wordle 游戏中，每局最多有 6 次猜词机会。
#
# 3. （单选题）上题中，猜词里的第二个 `L` 被标为 X，原因是什么？
#     A. 目标词中唯一可匹配的 `L` 已被前一个 `L` 使用
#     B. `L` 只能出现在单词首位
#     C. 重复字母统一标为 X
#     D. Wordle 只比较第一个重复字母
#
# 4. （单选题）按当前 verifier 的 `correct_answer` 规则，目标词为 `plane` 时，哪个 `<guess>` 内容能与答案精确匹配？
#     A. `<guess>plane</guess>`
#     B. `<guess>[plane]</guess>`
#     C. `<guess>[PLANE]</guess>`
#     D. `<answer>[plane]</answer>`
#
# 5. （单选题）当前 `_process_wordle_sample` 如何构造训练对话？
#     A. 按顺序拼接 `prompt` 和 `completion`
#     B. 只读取 `prompt`
#     C. 只读取 `completion`
#     D. 把 `answer` 追加到每条 user 消息
#
# 6. （单选题）对 token 序列 `t0, t1, t2, t3` 做 next-token 训练时，输入和右移标签应是？
#     A. 输入 `t0,t1,t2`；标签 `t1,t2,t3`
#     B. 输入 `t1,t2,t3`；标签 `t0,t1,t2`
#     C. 输入与标签都是 `t0,t1,t2,t3`
#     D. 只使用最后一个 token
#
# 7. （单选题）system/user 目标位置设为 `-100` 后，这些 token 如何参与训练？
#     A. 仍作为上下文，相关目标位置不计入 CE loss
#     B. 从输入序列中删除
#     C. 只参与 `format_reward` 计算
#     D. 作为 optimizer 的额外参数
#
# 8. （单选题）`format_reward=1` 最直接表明什么？
#     A. 回复满足评分器检查的 `<guess>` XML 格式要求
#     B. 回复一定猜中目标词
#     C. 回复一定满足全部 G/Y/X 约束
#     D. 模型已得到最优策略
#
# 9. （单选题）当前评测中，哪个指标用于记录猜词内容与目标答案的精确匹配？
#     A. `format_reward`
#     B. `correct_answer`
#     C. `length_bonus`
#     D. `partial_answer`
#
# 10. （多选题）本课程的 SFT 训练目标可以直接学习哪些内容？
#     A. 训练标签中的输出协议
#     B. 轨迹中的反馈条件行为
#     C. 环境奖励定义的最优策略
#     D. 未出现在训练数据中的评测答案

# %%
# !cat ./answer/01.04_answer.txt
