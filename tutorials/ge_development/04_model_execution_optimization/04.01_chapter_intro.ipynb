# %% [markdown]
# # 模型执行与优化：怎么高效执行
#
# > 一级章节：进阶开发 ｜ 二级模块：模型执行与优化
#
# 本模块从用户视角讲解静态 Shape 与动态 Shape 模型的执行流程，以及各自对应的执行优化技术，并用 profiling 数据验证优化收益。
#
# ---
#
# ## 章节目标
# 完成本章后，你将能够：
#
# - 理解静态 Shape 整图下沉执行流程并能验证收益
# - 理解动态 Shape Host 调度执行流程与开销来源
# - 掌握静态 Shape 场景下的执行优化技术
# - 掌握动态 Shape 场景下的执行优化技术
#
# ## 章节内容
# * [4.1 章节介绍](04.01_chapter_intro.ipynb)
# * [4.2 静态 Shape 执行流程](04.02_static_shape_execution.ipynb)
# * [4.3 动态 Shape 执行流程](04.03_dynamic_shape_execution.ipynb)
# * [4.4 静态 Shape 执行优化技术](04.04_static_shape_optimization.ipynb)
# * [4.5 动态 Shape 执行优化技术](04.05_dynamic_shape_optimization.ipynb)
# * [4.6 章节练习](04.06_chapter_practice.ipynb)
#
# ---
#
# 本章课程请从 [静态 Shape 执行流程](04.02_static_shape_execution.ipynb) 开始学习。
