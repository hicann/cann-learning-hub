# %% [markdown]
# # 实践与问题定位
#
# > 一级章节：高阶应用 ｜ 二级模块：实践与问题定位
#
# 本模块介绍 GE 与 PyTorch、TensorFlow 的接入方法，以及编译失败和运行时错误的定位步骤。
#
# ---
#
# ## 章节目标
# 完成本章后，你将能够：
#
# - 理解 GE 对接 PyTorch（TorchAir 图模式）的路径与使用边界
# - 掌握 GE 对接 TensorFlow 的接入方法与约束
# - 读懂 GE 错误码与日志，定位编译失败与运行时错误
#
# ## 章节内容
# * [5.1 章节介绍](05.01_chapter_intro.ipynb)
# * [5.2 GE 对接 PyTorch](05.02_pytorch_integration.ipynb)
# * [5.3 GE 对接 TensorFlow](05.03_tensorflow_integration.ipynb)
# * [5.4 常见问题定位方法](05.04_troubleshooting.ipynb)
# * [5.5 章节练习](05.05_chapter_practice.ipynb)
#
# ---
#
# 本章课程请从 [GE 对接 PyTorch](05.02_pytorch_integration.ipynb) 开始学习。
