# %% [markdown]
# # Vector算子开发
# 本章聚焦Vector算子的Tiling开发、网络中的算子调用方式，以及泛化算子开发的核心要点，帮助你掌握针对不同规模输入数据设计优化Tiling策略的方法，最终开发出支持任意输入大小的高效算子。
#
# ---
#
# ## 前置要求
# 为了充分掌握本章内容，你应已具备以下能力：
# - 完成第一章学习，理解算子的核心概念与基本原理。
# - 完成第二章学习，掌握基于Ascend C进行算子开发的基础方法。
#
#
# 在环境配置方面，本章课程要求对你的环境满足以下条件：
# - 系统中已部署昇腾NPU硬件，或已配置昇腾云服务器/仿真环境。
# - 已按照[CANN下载页面](https://www.hiascend.com/cann/download)完成对应硬件的开发环境部署。
#
# ---
#
# ## 章节目标
# 完成本课程后，你将能够：
# - 理解Tiling的基本原理。
# - 掌握单算子API调用和pybind调用。
# - 掌握任意输入大小时Tiling的设计和实现。
#
# ## 章节内容
# * [3.1 章节介绍](./03.01_chapter_intro.ipynb)
# * [3.2 工程化算子开发介绍](./03.02_operator_engineering_intro.ipynb)
# * [3.3 aclnn和pybind调用](./03.03_acl_pybind_call.ipynb)
# * [3.4 泛化Tiling设计](./03.04_generalized_tiling_design.ipynb)
# * [3.5 workspace介绍](./03.05_workspace_intro.ipynb)
# * [3.6 章节练习](./03.06_chapter_practice.ipynb)
#
# ---
#
# 本章课程请从[工程化算子开发介绍](./03.02_operator_engineering_intro.ipynb)开始学习。
