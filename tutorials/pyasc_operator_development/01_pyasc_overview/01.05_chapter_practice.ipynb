# %% [markdown]
# # 章节实践
#
# 通过本章的系统学习，我们已经掌握了 PyAsc 的项目定位、架构组成、安装流程和样例运行方式。本节作为综合实践，请独立完成以下任务，检验本章的学习效果。
#
# **实践目标**：从 0 完成 PyAsc 开发环境搭建，并在 NPU 上板模式下跑通课程提供的 `01_add` 与 `02_add_framework` 两个样例。

# %% [markdown]
# ---
#
# ## Step 1：环境自检
#
# **任务说明**：完成以下 3 项检查：
#
# 1. 检查 NPU 驱动是否正常（参考 1.4 节『1.2 开发环境验证』中提到的命令）。
# 2. 检查 CANN toolkit 与 CANN ops 的安装信息（参考 1.4 节 1.1 软硬件配套关系）。
# 3. 检查 `ASCEND_HOME_PATH` 环境变量是否已通过 `source set_env.sh` 设置。

# %%
# 待补充：依次完成上述 3 项环境自检

# %% [markdown]
# ---
#
# ## Step 2：安装 PyAsc 并验证
#
# **任务说明**：完成 PyAsc 的安装并验证安装成功（参考 1.4 节 2.1 与 2.3）：
#
# 1. 使用 pip 快速安装方式安装 PyAsc。
# 2. 通过 `pip3 list` 命令验证 `pyasc` 包是否已安装。
#
# > 本节实践仅要求跑通已有样例，使用 pip 快速安装即可，无需进行源码编译。

# %%
# 待补充：安装 PyAsc 并验证是否安装成功

# %% [markdown]
# ---
#
# ## Step 3：在运行环境中配置 CANN 环境变量
#
# **任务说明**：要跑通 PyAsc 样例，需要在**运行环境**中按 PyAsc 文档原文执行 CANN 环境变量配置（参考 1.4 节 3.1 source CANN 环境变量）。

# %%
# 待补充：写出在运行环境中配置 CANN 环境变量的命令

# %% [markdown]
# ---
#
# ## Step 4：跑通 `01_add` 样例
#
# **任务说明**：使用 1.4 节 3.2 介绍的 `-r RUN_MODE -v SOC_VERSION` 参数，在 NPU 上板模式下运行课程内 `./src/tutorials/01_add/add.py`。预期输出末尾包含：
#
# ```
# INFO:root:[INFO] Sample add run success.
# ```

# %%
# 待补充：以 NPU 上板模式运行 01_add 样例

# %% [markdown]
# ---
#
# ## Step 5：跑通 `02_add_framework` 样例
#
# **任务说明**：用同样的方式运行课程内 `./src/tutorials/02_add_framework/add_framework.py`。预期输出末尾包含：
#
# ```
# INFO:root:[INFO] Sample add_framework run success.
# ```

# %%
# 待补充：以 NPU 上板模式运行 02_add_framework 样例

# %% [markdown]
# ---
#
# ## 答案
#
# 完成上述步骤后，执行以下代码获取完整答案与对照。

# %%
# !cat ./answer/01.05_answer.txt
