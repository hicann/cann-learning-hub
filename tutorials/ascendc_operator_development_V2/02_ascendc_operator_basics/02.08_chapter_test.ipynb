# %% [markdown]
# # 2.8 章节测试
# 完成以下题目检验第二章学习效果，在每题下方的代码框中输入选项字母后运行。判断题 A=正确，B=错误。

# %% [markdown]
# **第1题**（单选题）C API Add 样例中，片上内存用哪种限定符声明？
# - A. __gm__
# - B. __ubuf__
# - C. __ca__
# - D. __cc__

# %%
q1 = ''  # 填入你的选项，如 'A'，修改后务必运行本单元格（Shift+Enter）
print(f'第1题答案已记录：{q1}' if q1 else '请填入答案并运行本单元格')

# %% [markdown]
# **第2题**（单选题）Tensor API Matmul 中 GM->L1 搬运自动完成哪种格式转换？
# - A. ND->ND
# - B. ND->NZ
# - C. NZ->ZN
# - D. ZN->ND

# %%
q2 = ''  # 填入你的选项，如 'A'，修改后务必运行本单元格（Shift+Enter）
print(f'第2题答案已记录：{q2}' if q2 else '请填入答案并运行本单元格')

# %% [markdown]
# **第3题**（单选题）SIMT Gather 启动参数 <<<48, 256>>> 的含义是？
# - A. 48 核、256 次循环
# - B. 48 个线程块、每块 256 线程
# - C. 48 线程、256 核
# - D. 48 字节、256 对齐

# %%
q3 = ''  # 填入你的选项，如 'A'，修改后务必运行本单元格（Shift+Enter）
print(f'第3题答案已记录：{q3}' if q3 else '请填入答案并运行本单元格')

# %% [markdown]
# **第4题**（判断题）C API Add 算子可以在 910B/910C 上运行。
# - A. 正确
# - B. 错误

# %%
q4 = ''  # 填入你的选项，如 'A'，修改后务必运行本单元格（Shift+Enter）
print(f'第4题答案已记录：{q4}' if q4 else '请填入答案并运行本单元格')

# %% [markdown]
# **第5题**（判断题）Tensor API Matmul 样例支持 910B/910C。
# - A. 正确
# - B. 错误

# %%
q5 = ''  # 填入你的选项，如 'A'，修改后务必运行本单元格（Shift+Enter）
print(f'第5题答案已记录：{q5}' if q5 else '请填入答案并运行本单元格')

# %% [markdown]
# **第6题**（判断题）SIMT 中每个线程通过 threadIdx.x 获取块内线程编号。
# - A. 正确
# - B. 错误

# %%
q6 = ''  # 填入你的选项，如 'A'，修改后务必运行本单元格（Shift+Enter）
print(f'第6题答案已记录：{q6}' if q6 else '请填入答案并运行本单元格')

# %% [markdown]
# **全部作答完成后，运行下方代码查看批改结果：**

# %%
import sys
sys.path.insert(0, './answer')
from grade import grade
grade(globals(), '02.08_answer.txt')
