# %% [markdown]
# # 章节练习
#
# 本章节练习用于综合检查 AutoFuse 基础介绍相关内容的学习效果，重点考察你是否能够把 AutoFuse 的定位、收益来源和基础使能方式串联起来。
#
# 1. （判断题）AutoFuse 属于图编译流程中的自动融合能力，普通使用者通常通过环境变量和模型编译入口间接使用，而不是把它当作一个运行时业务 API 直接调用。
#
# 2. （判断题）如果模型中存在 Reduce 或 Concat 结构，只要设置 `--enable_autofuse=true`，Reduce 和 Concat 融合能力就一定已经开启。
#
# 3. （单选题）结合 FusedGraph 结构图，以下哪种描述更符合 AutoFuse 前端确定融合范围后的表达方式？
#     A. FusedGraph 用来表达一个融合范围，内部可以包含一个或多个 AscBackend 节点
#     B. FusedGraph 是用户手写的业务模型代码，编译阶段不会再转换它
#     C. FusedGraph 只表示单个原始算子，不能表达多个算子组成的融合范围
#     D. FusedGraph 只用于运行时调度，与图编译阶段的自动融合无关
#
# 4. （单选题）关于 AutoFuse 的两条接入路线，以下哪种理解更符合本章节介绍？
#     A. GE 框架路径注重图模式融合，PyTorch Inductor 路径注重生态对接，二者最终都会对接 Ascend C IR 与代码生成等底层能力
#     B. GE 框架路径只负责产品型号检测，不参与融合范围识别和图表达转换
#     C. PyTorch Inductor 路径完全绕过 Ascend C IR，因此无法复用 AutoFuse 的后端生成能力
#     D. 两条接入路线互相排斥，学习 AutoFuse 时只能选择其中一条理解
#
# 5. （多选题）普通使用者希望验证 AutoFuse 基础开关是否设置到当前环境，应重点检查哪些信息？
#     A. CANN 环境变量是否已经正确加载
#     B. `AUTOFUSE_FLAGS` 是否在当前执行环境中设置
#     C. 模型是否通过 ATC 等可触发 GE 图编译的入口生成编译产物
#     D. 模型推理精度是否满足预期
#
# 6. （多选题）如果开启 AutoFuse 后没有明显性能收益，以下哪些分析方向更合理？
#     A. 检查模型瓶颈是否主要来自 Memory Bound，而不是其他大计算算子
#     B. 检查模型中的算子类型、shape 和融合范围是否满足融合条件
#     C. 使用 profiling、编译日志或 DFX 信息对比开启前后的差异
#     D. 直接认定 AutoFuse 功能失效，因为开启后必须提升性能
#
# 7. （多选题）关于 AutoFuse 基础使能方式，以下说法正确的是哪些？
#     A. `AUTOFUSE_FLAGS` 用于控制 AutoFuse 是否开启以及启用哪些基础融合能力
#     B. `AUTOFUSE_DFX_FLAGS` 属于进阶定位和调优配置，不是基础使能必需项
#     C. Reduce、Concat 默认不使能，需要按场景通过 pass 显式开启
#     D. 开启 AutoFuse 后可以默认认为所有模型都有明显性能收益
#
# **执行以下代码获取答案。**

# %%
# !cat ./answer/01.04_answer.txt
