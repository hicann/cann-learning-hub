# %% [markdown]
# # 章节练习
#
# 本章介绍了 Wordle 任务和 SFT 的核心概念。请根据学习内容完成以下题目进行自测。
#
# ---
#
# ## 选择题

# %% [markdown]
# 1. （判断题）Wordle 是一个多轮猜词游戏，每轮最多猜 7 次。
#
# 2. （判断题）SFT 训练的目标是直接让模型学会最优猜词策略。
#
# 3. （判断题）Label Masking 的作用是屏蔽 user 和 system 消息对应的 token，只在 assistant 回复上计算 loss。
#
# 4. （判断题）SFT 训练数据中的游戏记录是由最优策略生成的，以保证模型学到最佳策略。
#
# 5. （单选题）Wordle 游戏中，G/Y/X 反馈分别表示什么？
#     A. Good / Yellow / Bad
#     B. Green（位置对）/ Yellow（字母对但位置错）/ X（字母不在词中）
#     C. Great / Yes / No
#     D. 大 / 中 / 小
#
# 6. （单选题）SFT 在 Wordle 两阶段训练中最重要的作用是？
#     A. 让模型学会最优猜词策略
#     B. 让模型学会输出格式正确的猜测（format_reward 0.2 → 1.0）
#     C. 让模型学会自然语言对话
#     D. 减少模型参数量
#
# 7. （单选题）SFT 的损失函数是什么？
#     A. Policy Gradient Loss
#     B. KL Divergence
#     C. Cross-Entropy Loss
#     D. Mean Squared Error Loss
#
# 8. （单选题）SFT 与 Pretraining 在数据格式上的核心区别是什么？
#     A. SFT 使用图片数据，预训练使用文本数据
#     B. SFT 使用对话格式（messages），预训练使用任意文本
#     C. SFT 不需要数据，预训练需要大量数据
#     D. 没有区别
#
# 9. （多选题）以下哪些是 SFT 在 Wordle 两阶段训练中扮演的角色？
#     A. 格式对齐（Format Alignment）
#     B. 反馈理解（Feedback Comprehension）
#     C. 最优策略学习（Optimal Strategy Learning）
#     D. 初步策略（Initial Strategy）
#
# 10. （多选题）Wordle 评测指标中包含以下哪些？
#     A. format_reward
#     B. correct_answer
#     C. bleu_score
#     D. length_bonus

# %%
# !cat ./answer/01.04_answer.txt
