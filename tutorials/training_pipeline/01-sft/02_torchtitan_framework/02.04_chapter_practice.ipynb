# %% [markdown]
# # 章节练习
#
# 本章介绍了 FSDP 分布式训练、TorchTitan 框架以及环境配置。请根据学习内容完成以下题目进行自测。
#
# ---
#
# ## 选择题

# %% [markdown]
# 1. （判断题）FSDP 把模型参数切成 N 份，每张卡只存 1/N。正向时需要 all-gather 拼成完整模型再各自计算。
#
# 2. （判断题）FSDP 反向传播时使用 reduce-scatter——先求和（reduce）得到完整梯度，再分发（scatter）回各卡。直接 scatter 拿不到完整梯度。
#
# 3. （判断题）环境验证使用 debug 模式，需要一个提前下载的真实模型权重文件。
#
# 4. （单选题）`model_registry("1.7B")` 中 `parallelize_fn=parallelize_qwen3` 的作用是什么？
#     A. 下载数据集
#     B. 将模型参数按 FSDP 策略分片到多卡
#     C. 转换模型为 ONNX 格式
#     D. 启动 Web 服务器
#
# 5. （单选题）FSDP 的 FULL_SHARD 分片策略相比 DDP（每卡完整副本）的主要优势是什么？
#     A. 训练速度更快
#     B. 单卡显存占用更低
#     C. 通信开销为零
#     D. 模型精度更高
#
# 6. （单选题）以下哪个不是 FSDP 的参数管理方式？
#     A. all-gather：正向时拼出完整参数
#     B. reduce-scatter：反向时求和并分发梯度
#     C. broadcast：广播完整参数到所有卡
#     D. 用完即弃：不用的完整参数立即释放
#
# 7. （多选题）TorchTitan 的设计目标包括以下哪些？
#     A. 把 FSDP 包装成开箱即用的训练框架
#     B. 支持通过配置切换模型和数据
#     C. 提供声明式插件机制（ModelConverter，第 4 章详述）
#     D. 代替 PyTorch 基础框架
#
# 8. （多选题）环境配置的前置条件包括以下哪些？
#     A. CANN 9.0.0 已安装
#     B. torch_npu 可用
#     C. Docker 必须安装
#     D. `npu-smi info` 可用

# %%
# !cat ./answer/02.04_answer.txt
