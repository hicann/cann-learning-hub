# %% [markdown]
# # 章节练习
#
# 本章介绍了超参数调优和训练崩溃分析。请根据学习内容完成以下题目进行自测。
#
# ---
#
# ## 选择题

# %% [markdown]
# 1. （判断题）entropy_coeff=0（默认值）时，模型没有任何探索保护机制，可能导致策略崩塌。
#
# 2. （判断题）entropy_coeff 越大越好，可以充分保证模型的探索能力。
#
# 3. （判断题）RL 的学习率通常比 SFT 低 1-2 个数量级。
#
# 4. （判断题）策略崩塌的根因是三种力失衡——策略梯度压过了 KL 正则和 entropy bonus。
#
# 5. （判断题）KL loss 和 entropy bonus 是互补的稳定性机制，KL 限制方向，entropy 限制分布形状。
#
# 6. （判断题）训练监控时只需要看 reward 一个指标即可判断训练健康度。
#
# 7. （判断题）策略崩塌通常发生在训练早期（前 100 步）。
#
# 8. （单选题）entropy_coeff=0.01 导致 entropy 飙升到 4.51，说明什么？
#     A. KL 正则太强
#     B. Entropy bonus 过强，压过了策略梯度
#     C. 学习率太低
#     D. 训练正常
#
# 9. （单选题）崩溃训练中 reward 降到 0.20，这个 0.20 来自哪里？
#     A. correct_answer
#     B. partial_answer
#     C. format_reward (0.2 * 1.0)
#     D. length_bonus
#
# 10. （单选题）以下哪个是修复策略崩塌的有效方案？
#     A. 降低 entropy_coeff
#     B. 加 entropy_coeff=0.005
#     C. 提高学习率
#     D. 减小 batch size
#
# 11. （多选题）以下哪些超参数影响 RL 训练稳定性？
#     A. entropy_coeff
#     B. kl_loss_coef
#     C. ACTOR_LR
#     D. ROLLOUT_N
#
# 12. （多选题）崩溃诊断流程中需要检查哪些指标？
#     A. entropy
#     B. response_length
#     C. correct 率
#     D. grad_norm
#
# 13. （多选题）以下哪些是策略崩塌的典型表现？
#     A. entropy 突然跌到 0
#     B. correct 率归零
#     C. response_length 全部打满
#     D. reward 降到仅 format 分
#
# 14. （多选题）以下哪些是训练监控的最佳实践？
#     A. 前 50 步密切监控
#     B. 设置 checkpoint 频率
#     C. 只看 reward 一个指标
#     D. 同时看多个指标

# %%
# !cat ./answer/04.04_answer.txt
