# %% [markdown]
# # 第三章 章节练习
#
# 恭喜你完成了 **npugraph_ex 基础功能** 的学习！
# 本节将对本章所学知识进行巩固和检测。请先独立完成题目，再运行文末代码单元查看参考答案与解析。
#
# ---

# %% [markdown]
# ### 一、判断题
#
# 1. `input_inplace_pass` 会删除所有 Python `copy_` 操作。（ ）
# 2. `clone_output=True` 可以避免 Replay 覆盖被长期持有的输出。（ ）
# 3. `use_graph_pool` 和 `reuse_graph_pool_in_same_fx` 的复用范围完全相同。（ ）
# 4. FX Pass 修改后必须重新验证数值和性能。（ ）
#
# ---
#
# ### 二、单选题
#
# 5. 恢复支持场景中的输入原地更新使用哪个配置？
#    - A. clone_output
#    - B. input_inplace_pass
#    - C. force_eager
#    - D. static_kernel_compile
#
# 6. 大输入开启 clone_input=True 可能带来什么代价？
#    - A. 额外输入拷贝和显存占用
#    - B. 关闭 Dynamo
#    - C. 自动切换 CPU
#    - D. 删除模型参数
#
# 7. pattern_fusion_pass 的主要作用是什么？
#    - A. 修改 Python 控制流
#    - B. 将匹配的 FX 子图替换为融合算子
#    - C. 强制每次重新 Capture
#    - D. 设置 Vector Core 数量
#
# ---
#
# ### 三、多选题
#
# 8. 哪些做法有助于验证 FX Pass 生效？
#    - A. 查看优化前后的 FX 图
#    - B. 与 Eager 结果做精度对比
#    - C. 使用 Profiler 比较算子和内存
#    - D. 只观察首次执行时间
#
# ---
#
# ### 四、实验题
#
# 比较 clone_output=False 和 clone_output=True，保存第一次输出并在第二次 Replay 后比较结果；记录两种配置的数值、内存和耗时差异。

# %%
import os
answer_path = "answer/03.06_answer.txt"
if os.path.exists(answer_path):
    with open(answer_path, "r", encoding="utf-8") as f:
        print(f.read())
else:
    print("答案文件未找到，请检查 ./answer/ 目录结构。")

# %% [markdown]
# **[实验题参考代码](./answer/03.06_answer.ipynb)**
