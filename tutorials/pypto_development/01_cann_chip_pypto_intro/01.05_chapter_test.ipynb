# %% [markdown]
# # 章节实践
#
# 本节用于完成第一章的综合自测。完成练习时，可以把重点放在三件事上：CANN、昇腾芯片和 PyPTO 分别处在什么层级；它们在算子开发链路中如何协作；为什么 PyPTO 要围绕 Tensor、Tile 和多层级计算图组织计算。

# %% [markdown]
# ## 1. 实践目标
#
# 完成本节后，读者应能够：
#
# 1. 区分昇腾芯片、CANN 和 PyPTO 的定位。
# 2. 说明从 PyPTO 代码到芯片执行的大致链路。
# 3. 理解 Tile 编程模型与芯片内存层次、并行计算之间的关系。
# 4. 判断 PyPTO 适合解决的算子开发问题。

# %% [markdown]
# ## 2. 章节实践题
#
# 题型包含选择题和填空题。建议先独立完成，再执行下一单元查看参考答案。
#
# 1. （选择题）下面哪一项最准确描述了 CANN、昇腾芯片和 PyPTO 的关系？
#    A. PyPTO 直接替代昇腾芯片执行所有计算
#    B. CANN 是硬件芯片，PyPTO 是驱动固件
#    C. 昇腾芯片提供硬件算力，CANN 提供软件栈支撑，PyPTO 提供面向算子开发的 Python 编程接口
#    D. 三者都只用于模型数据集管理
#
# 2. （填空题）从开发者代码到芯片执行，可以概括为：开发者使用________描述计算，经过________编译、优化和调度，最终在________上执行。
#
# 3. （选择题）PyPTO 引入 Tile 编程模型的主要原因是什么？
#    A. 让所有变量都变成字符串
#    B. 适配芯片的多级内存层次和并行计算单元，把大 Tensor 的计算拆分成更适合搬运、缓存和执行的数据块
#    C. 只为了减少 notebook 的数量
#    D. 只为了隐藏 Python 语法
#
# 4. （填空题）PyPTO 多层级计算图包括 Tensor Graph、Tile Graph、\_\_\_和\_\_\_。
#
# 5. （选择题）下面哪类场景更适合使用 PyPTO？
#    A. 自定义算子、融合算子、大模型组件优化和动态 Shape 处理
#    B. 文档排版
#    C. 网页路由管理
#    D. 图片压缩格式转换
#
# 6. （填空题）CANN Toolkit 通常提供编译、调试、调优和运行支持等能力，它是上层框架访问________硬件的重要基础。
#
# 7. （选择题）学习 PyPTO 前先了解 CANN 和芯片基础，主要是为了什么？
#    A. 只记住更多名词，不影响后续开发
#    B. 理解算子表达、编译优化、内存访问和硬件执行之间的关系
#    C. 避免使用 Python 代码
#    D. 跳过算子验证流程

# %% [markdown]
# ## 3. 查看答案
#
# 执行以下代码获取参考答案。

# %%
# !cat ./answer/01.05_answer.txt

# %% [markdown]
# ## 4. 本章小结
#
# 第一章建立了 PyPTO 算子开发的基础认知：昇腾芯片是硬件算力基础，CANN 是连接硬件与上层框架的软件栈，PyPTO 是面向算子开发的 Python 编程框架。后续进入算子开发基础和算子实践时，可以始终沿着“开发者代码 -> PyPTO -> CANN -> 昇腾芯片”这条链路理解每一步的作用。
