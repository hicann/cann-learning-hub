# %% [markdown]
# # 07_巧用排序算法优化MoE融合算子——测试参考答案
#
# 本文件仅用于复盘，请先独立完成主 Notebook。

# %% [markdown]
# ## 一、选择题
#
# 1. B：TopK 维护大小为 K 的堆。
# 2. B：910B 的示例 BLOCK_DIM 为 16。
# 3. B：sortedOrder 是按 expert 分桶后的 token-slot 顺序。

# %% [markdown]
# ## 二、填空题
#
# 1. `blockDim`。
# 2. `ascend910b`。
# 3. `权重`。

# %% [markdown]
# ## 三、实践题
#
# 参考要点见 `moe_sort_lab_answer.md`。关键是说明三种 route 的选择逻辑、910B 的 Host tiling 适配，以及完整路径中 `order+copy`、Permute、Unpermute 的时间归属。
